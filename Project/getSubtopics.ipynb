# %% [markdown]
# We have a list of quotes extracted from Art wikiquote website. Every quote will be a node in the network we will build.
#
# The edges between the nodes will be the common subtopics they share. The purpose of this notebook is to get these subtopics from the quotes.

# %%
import nltk
